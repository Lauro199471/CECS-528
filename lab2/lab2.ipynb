# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def getY(formula, x_range):  
    x = np.array(x_range)  
    y = eval(formula) 
    return x,y

# %%
x1,y1 = getY("(x**3)+(20*x)+1", range(0, 30));

plt.plot(x1,y1,"green");
plt.grid();
plt.title('f(x) = (x^3) + 20x + 1');
plt.savefig('f(x)');

# %%
x2,y2 = getY("(x**3)", range(0, 30))

plt.plot(x2,y2,"blue");
plt.grid();
plt.title('g(x) = (x^3)');
plt.savefig('g(x)');

# %%
plt.plot(x1,y1,'green',x2,y2,"blue");
plt.grid();
plt.title('f(x) = (x^3) + 20x + 1\ng(x)=(x^3)');
plt.savefig('f(x)&g(x)');

# %%
for x in range(1, 30):
    print(x)
# Out:
# 2
# 3
# 4
# 5
