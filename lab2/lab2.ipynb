# %%
import numpy as np
import matplotlib.pyplot as plt  
import math

# %%
x = np.arange(.001,5,.01);

# %%
fx =  x * np.log2(x);

plt.plot(x,fx,"green");
plt.axhline(y=0, color='black', linestyle='-' )
plt.axvline(x=0, color='black', linestyle='-')
plt.grid();
plt.title('f(x) = xlogx');
plt.savefig('f(x)');

# %%
gx = x + (2*x*np.log2(x));

plt.plot(x,gx,"blue");
plt.axhline(y=0, color='black', linestyle='-')
plt.axvline(x=0, color='black', linestyle='-')
plt.grid();
plt.title('g(x) = x + xlogx^2');
plt.savefig('g(x)');

# %%
plt.plot(x,fx,'green',x,gx,"blue");
plt.axhline(y=0, color='black', linestyle='-')
plt.axvline(x=0, color='black', linestyle='-')
plt.grid();

plt.title('Show f(x)(green) = O(g(x)(blue))');
plt.savefig('f(x)&g(x)');

# %%
maxList = [];
for i in range(0 , x.size):
    if fx[i] > gx[i]:
        maxList.append(fx[i]);
    
    elif gx[i] > fx[i]:
        maxList.append(gx[i])
    
    elif gx[i] == fx[i]:
        maxList.append(gx[i])

plt.plot(x,maxList,"red" , linewidth = 8);
plt.plot(x,fx,'green',x,gx,"blue");
plt.axhline(y=0, color='black', linestyle='-')
plt.axvline(x=0, color='black', linestyle='-')
plt.grid();
plt.title('f(x)(green) + g(x)(blue) = Θ(max(f(x),g(x))(red))');
plt.savefig('f(x)Cg(x)1');
plt.show();
plt.close();

# %%
c =  1/3;
n0 = 2;

plt.plot(x,np.multiply(c , gx),'blue',linestyle='-');
plt.plot(x,fx,'green');

plt.axvline(x=n0, color='red', linestyle='-');
plt.axhline(y=0, color='black', linestyle='-');
plt.axvline(x=0, color='black', linestyle='-');


plt.grid();
plt.title('Big Ω: f(x)(green) => Cg(x))(blue) , where C = 1/3 , n>=2');
plt.savefig('f(x)Cg(x)2');
plt.show();
plt.close();
